# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("top-5000-youtube-channels.csv")

# %%
df
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
df.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
df.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %%
df.shape
# Out:
# (5000, 6)

# %%
print("Number of rows :",df.shape[0])
print("Number of columns : ",df.shape[1])
# Out:
# Number of rows : 5000
# Number of columns :  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
pd.options.display.float_format ="{:2f}".format

# %%
df.describe()
# Out:
#              Video views
# count        5000.000000
# mean   1071449400.150000
# std    2003843972.123991
# min            75.000000
# 25%     186232945.750000
# 50%     482054780.000000
# 75%    1124367826.750000
# max   47548839843.000000

# %%
df.head(30)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df = df.replace("--",np.nan,regex = True)

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
nul_val = df.isnull().sum()  * 100 / len(df)

# %%
nul_val
# Out:
# Rank            0.000000
# Grade           0.000000
# Channel name    0.000000
# Video Uploads   0.120000
# Subscribers     7.740000
# Video views     0.000000
# dtype: float64

# %%
df.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
df['Rank'] = df['Rank'].str[:-2]

# %%
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1  A++                       Zee TV         82757    18752951
# 1    2  A++                     T-Series         12661    61196302
# 2    3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4  A++                    SET India         27323    31180559
# 4    5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df['Rank'] = df['Rank'].str.replace(",", "").astype('int')

# %%
df.head(-5)
# Out:
#       Rank  Grade                      Channel name  Video Uploads  \
# 0        1    NaN                            Zee TV   82757.000000
# 1        2    NaN                          T-Series   12661.000000
# 2        3    NaN        Cocomelon - Nursery Rhymes     373.000000
# 3        4    NaN                         SET India   27323.000000
# 4        5    NaN                               WWE   36756.000000
# ...    ...    ...                               ...            ...
# 4990  4991    NaN     Ho Ngoc Ha's Official Channel     208.000000
# 4991  4992    NaN              Toys to Learn Colors      11.000000
# 4992  4993    NaN                             КАZКА      25.000000
# 4993  4994    NaN  United CUBE (CUBE Entertainment…    1055.000000
# 4994  4995    NaN                     Wings Marathi    1735.000000
#
#          Subscribers  Video views        avg_viws
# 0    18752951.000000  20869786591   252181.526529
# 1    61196302.000000  47548839843  3755535.885238
# ...

# %%
df.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
df.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
df['Video Uploads'] = df['Video Uploads'].astype('float')

# %%
df['Subscribers'] = df['Subscribers'].astype('float')

# %%
df.dtypes
# Out:
# Rank               int32
# Grade             object
# Channel name      object
# Video Uploads    float64
# Subscribers      float64
# Video views        int64
# dtype: object

# %%
df['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', '\xa0 ', 'A- ', 'B+ '], dtype=object)

# %%
df['Grade'] = df['Grade'].map({'A++ ':5, 'A+ ':4, 'A ':3, 'A- ':2, 'B+ ':1})

# %%
df['Grade']
# Out:
# 0      5.000000
# 1      5.000000
# 2      5.000000
# 3      5.000000
# 4      5.000000
#          ...
# 4995   1.000000
# 4996   1.000000
# 4997   1.000000
# 4998   1.000000
# 4999   1.000000
# Name: Grade, Length: 5000, dtype: float64

# %%
df.head()
# Out:
#    Rank    Grade                Channel name  Video Uploads     Subscribers  \
# 0     1 5.000000                      Zee TV   82757.000000 18752951.000000
# 1     2 5.000000                    T-Series   12661.000000 61196302.000000
# 2     3 5.000000  Cocomelon - Nursery Rhymes     373.000000 19238251.000000
# 3     4 5.000000                   SET India   27323.000000 31180559.000000
# 4     5 5.000000                         WWE   36756.000000 32852346.000000
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df['avg_viws'] = df['Video views'] / df['Video Uploads']

# %%
df.head()
# Out:
#    Rank    Grade                Channel name  Video Uploads     Subscribers  \
# 0     1 5.000000                      Zee TV   82757.000000 18752951.000000
# 1     2 5.000000                    T-Series   12661.000000 61196302.000000
# 2     3 5.000000  Cocomelon - Nursery Rhymes     373.000000 19238251.000000
# 3     4 5.000000                   SET India   27323.000000 31180559.000000
# 4     5 5.000000                         WWE   36756.000000 32852346.000000
#
#    Video views        avg_viws
# 0  20869786591   252181.526529
# 1  47548839843  3755535.885238
# 2   9793305082 26255509.603217
# 3  22675948293   829921.615233
# 4  26273668433   714813.049108

# %%
df.sort_values(by= 'Video Uploads',ascending = False).head()
# Out:
#       Rank    Grade Channel name  Video Uploads    Subscribers  Video views  \
# 3453  3454 1.000000   AP Archive  422326.000000  746325.000000    548619569
# 1149  1150 2.000000     YTN NEWS  355996.000000  820108.000000   1640347646
# 2223  2224 1.000000    SBS Drama  335521.000000 1418619.000000   1565758044
# 323    324 3.000000     GMA News  269065.000000 2599175.000000   2786949164
# 2956  2957 1.000000          MLB  267649.000000 1434206.000000   1329206392
#
#          avg_viws
# 3453  1299.042846
# 1149  4607.769879
# 2223  4666.646928
# 323  10357.902975
# 2956  4966.229622

# %%
df.groupby('Grade').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# ...
